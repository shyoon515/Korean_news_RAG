# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../")

# %%
from pipeline.generator.llm import VLLMGenerator
lg = "LGAI-EXAONE/EXAONE-4.0-1.2B"
kt = "K-intelligence/Midm-2.0-Mini-Instruct"
naver= "naver-hyperclovax/HyperCLOVAX-SEED-Text-Instruct-1.5B"

generator = VLLMGenerator(
    model_name="exaone",
    api_base="http://localhost:8000/v1",
)

# %%
outputs = generator.generate(prompts=["오늘의 날씨는?", "한국의 수도는?"])
# Out:
# [2025-12-18 14:05:44] INFO _client.py:1025: HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-12-18 14:05:44] INFO _client.py:1025: HTTP Request: POST http://localhost:8000/v1/chat/completions "HTTP/1.1 200 OK"

# %%
outputs
# Out:
# ['오늘의 날씨에 대한 정보를 제공해드릴 수 있습니다. 어떤 지역의 날씨를 알고 싶으신가요?', '한국의 수도는 서울특별시입니다.']

# %%
llm.generate("Hello, my name is")
